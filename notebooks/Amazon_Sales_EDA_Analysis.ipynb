# %% [markdown]
# *Features*
#
# * **product_id** - Product ID
# * **product_name** - Name of the Product
# * **category** - Category of the Product
# * **discounted_price** - Discounted Price of the Product
# * **actual_price** - Actual Price of the Product
# * **discount_percentage** - Percentage of Discount for the Product
# * **rating** - Rating of the Product
# * **rating_count** - Number of people who voted for the Amazon rating
# * **about_product** - Description about the Product
# * **user_id** - ID of the user who wrote review for the Product
# * **user_name** - Name of the user who wrote review for the Product
# * **review_id** - ID of the user review
# * **review_title** - Short review
# * **review_content** - Long review
# * **img_link** - Image Link of the Product
# * **product_link** - Official Website Link of the Product

# %% [markdown]
# **Step 1  - Import the data**

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Loading the dataset
df = pd.read_csv('/content/sample_data/amazon_sales_data.csv')

#Show the first rows of the dataset
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# **Step 2 - Evaluate data quality**

# %%
#Verify general information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
#Verity duplicated rows
duplicated_rows= df.duplicated().sum()
print("Duplicated rows: ",duplicated_rows)
# Out:
# Duplicated rows:  0

# %%
#Verify null values
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# **Step 3 - Wrangle the dataset**

# %%
#Drop unnecessary columns
df= df.drop(['product_id','about_product','user_id','user_name','review_id','review_title','review_content','img_link','product_link'],axis=1)
df.head()
# Out:
#                                         product_name  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# ...

# %%
#Creating the first new column 'macro_category'
df['macro_category']= df['category'].str.split('|').str.get(0)
df.head()
# Out:
#                                         product_name  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count         macro_category
# 0       ₹1,099                 64%    4.2       24,269  Computers&Accessories
# ...

# %%
#Creating the second new column 'micro_category'
df['micro_category']= df['category'].str.split('|').str.get(-1)
df.head()
# Out:
#                                         product_name  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count         macro_category  \
# 0       ₹1,099                 64%    4.2       24,269  Computers&Accessories
# ...

# %%
#Drop column 'category'
df= df.drop(['category'],axis=1)
df.head()
# Out:
#                                         product_name discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             ₹399
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             ₹199
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             ₹199
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             ₹329
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             ₹154
#
#   actual_price discount_percentage rating rating_count         macro_category  \
# 0       ₹1,099                 64%    4.2       24,269  Computers&Accessories
# 1         ₹349                 43%    4.0       43,994  Computers&Accessories
# 2       ₹1,899                 90%    3.9        7,928  Computers&Accessories
# 3         ₹699                 53%    4.2       94,363  Computers&Accessories
# 4         ₹399                 61%    4.2       16,905  Computers&Accessories
#
#   micro_category
# 0      USBCables
# 1      USBCables
# 2      USBCables
# ...

# %%
#Transform the columns 'discounted_price' and 'actual_price' in float values
df['discounted_price']= df['discounted_price'].str.replace('₹','').str.replace(',', '').astype(float)
df['actual_price']= df['actual_price'].str.replace('₹','').str.replace(',', '').astype(float)
df.head()
# Out:
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
#
#    actual_price discount_percentage rating rating_count  \
# 0        1099.0                 64%    4.2       24,269
# 1         349.0                 43%    4.0       43,994
# 2        1899.0                 90%    3.9        7,928
# 3         699.0                 53%    4.2       94,363
# 4         399.0                 61%    4.2       16,905
#
#           macro_category micro_category
# 0  Computers&Accessories      USBCables
# 1  Computers&Accessories      USBCables
# 2  Computers&Accessories      USBCables
# ...

# %%
#Transform the column 'discount_percentage' in float values
df['discount_percentage']= df['discount_percentage'].str.replace('%', '').astype(float)
df['discount_percentage']= df['discount_percentage']/100
df.head()
# Out:
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
#
#    actual_price  discount_percentage rating rating_count  \
# 0        1099.0                 0.64    4.2       24,269
# 1         349.0                 0.43    4.0       43,994
# 2        1899.0                 0.90    3.9        7,928
# 3         699.0                 0.53    4.2       94,363
# 4         399.0                 0.61    4.2       16,905
#
#           macro_category micro_category
# 0  Computers&Accessories      USBCables
# 1  Computers&Accessories      USBCables
# 2  Computers&Accessories      USBCables
# ...

# %%
#Transform the column 'rating' in float values
df['rating'] = pd.to_numeric(df['rating'].str.replace('|', 'NaN'), errors='coerce')
df.head()
# Out:
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
#
#    actual_price  discount_percentage  rating rating_count  \
# 0        1099.0                 0.64     4.2       24,269
# 1         349.0                 0.43     4.0       43,994
# 2        1899.0                 0.90     3.9        7,928
# 3         699.0                 0.53     4.2       94,363
# 4         399.0                 0.61     4.2       16,905
#
#           macro_category micro_category
# 0  Computers&Accessories      USBCables
# 1  Computers&Accessories      USBCables
# 2  Computers&Accessories      USBCables
# ...

# %%
#Create column with rate description
df['rate_description']= pd.cut(df['rating'], bins=[1, 2, 3, 4, 5], labels=['Terrible','Poor', 'Average', 'Good'])
df.head()
# Out:
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
#
#    actual_price  discount_percentage  rating rating_count  \
# 0        1099.0                 0.64     4.2       24,269
# 1         349.0                 0.43     4.0       43,994
# 2        1899.0                 0.90     3.9        7,928
# 3         699.0                 0.53     4.2       94,363
# 4         399.0                 0.61     4.2       16,905
#
#           macro_category micro_category rate_description
# 0  Computers&Accessories      USBCables             Good
# 1  Computers&Accessories      USBCables          Average
# ...

# %%
#Transform the column 'rating_count' in float values
df['rating_count']= df['rating_count'].str.replace(',', '').astype(float)
df.head()
# Out:
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
# 1         349.0                 0.43     4.0       43994.0
# 2        1899.0                 0.90     3.9        7928.0
# 3         699.0                 0.53     4.2       94363.0
# 4         399.0                 0.61     4.2       16905.0
#
#           macro_category micro_category rate_description
# 0  Computers&Accessories      USBCables             Good
# 1  Computers&Accessories      USBCables          Average
# ...

# %%
#Verify null values
df.isnull().sum()
# Out:
# product_name           0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 1
# rating_count           2
# macro_category         0
# micro_category         0
# rate_description       1
# dtype: int64

# %%
#Drop null values
df= df.dropna()

# %%
#Verify general information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1462 entries, 0 to 1464
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_name         1462 non-null   object
#  1   discounted_price     1462 non-null   float64
#  2   actual_price         1462 non-null   float64
#  3   discount_percentage  1462 non-null   float64
#  4   rating               1462 non-null   float64
#  5   rating_count         1462 non-null   float64
#  6   macro_category       1462 non-null   object
#  7   micro_category       1462 non-null   object
#  8   rate_description     1462 non-null   category
# dtypes: category(1), float64(5), object(3)
# memory usage: 104.4+ KB

# %%
#Verify statistical information
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1462.000000    1462.000000          1462.000000  1462.000000
# mean        3129.981826    5453.087743             0.476724     4.096717
# std         6950.548042   10884.467444             0.216139     0.289497
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000             0.320000     4.000000
# 50%          799.000000    1670.000000             0.500000     4.100000
# 75%         1999.000000    4321.250000             0.630000     4.300000
# max        77990.000000  139900.000000             0.940000     5.000000
#
#         rating_count
# count    1462.000000
# mean    18307.376881
# std     42766.096572
# min         2.000000
# 25%      1191.500000
# 50%      5179.000000
# 75%     17342.250000
# max    426973.000000

# %%
#Show the top 5 most evaluated products in the 'product_name' column
pd.concat([df['product_name'].value_counts(), df['product_name'].value_counts(normalize=True).round(2)], axis=1).head(5)
# Out:
#                                                     count  proportion
# product_name
# Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watc...      5         0.0
# Fire-Boltt Phoenix Smart Watch with Bluetooth C...      4         0.0
# Ambrane Unbreakable 60W / 3A Fast Charging 1.5m...      3         0.0
# Duracell USB Lightning Apple Certified (Mfi) Br...      3         0.0
# Flix Micro Usb Cable For Smartphone (Black)             3         0.0

# %%
#Show the evaluated products in the 'product_macro_category' column
pd.concat([df['macro_category'].value_counts(), df['macro_category'].value_counts(normalize=True).round(2)], axis=1)
# Out:
#                        count  proportion
# macro_category
# Electronics              526        0.36
# Computers&Accessories    451        0.31
# Home&Kitchen             447        0.31
# OfficeProducts            31        0.02
# MusicalInstruments         2        0.00
# HomeImprovement            2        0.00
# Toys&Games                 1        0.00
# Car&Motorbike              1        0.00
# Health&PersonalCare        1        0.00

# %%
#Show the top 5 most evaluated products in the 'micro_category' column
pd.concat([df['micro_category'].value_counts(), df['micro_category'].value_counts(normalize=True).round(2)], axis=1).head(5)
# Out:
#                   count  proportion
# micro_category
# USBCables           231        0.16
# SmartWatches         76        0.05
# Smartphones          68        0.05
# SmartTelevisions     63        0.04
# In-Ear               52        0.04

# %%
#Show the proportion evaluated in the "rate_description" column
pd.concat([df['rate_description'].value_counts(), df['rate_description'].value_counts(normalize=True).round(2)], axis=1)
# Out:
#                   count  proportion
# rate_description
# Good                928        0.63
# Average             525        0.36
# Poor                  8        0.01
# Terrible              1        0.00

# %% [markdown]
# **Step 4 - Evaluete the behavior of the variables**

# %%
#Rating histogram
plt.figure(figsize=(8, 4))
sns.histplot(df['rating'], bins=20, kde=True)
plt.title('Rating Histogram')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
#Numeric correlation matrix
correlation_matrix = df.select_dtypes(include=np.number).corr()['rating']
target_correlation = np.abs(correlation_matrix)
print(target_correlation.sort_values(ascending=False))
# Out:
# rating                 1.000000
# discount_percentage    0.155679
# actual_price           0.122467
# discounted_price       0.121132
# rating_count           0.102235
# Name: rating, dtype: float64

# %%
#Correlation matrix graph
plt.figure(figsize=(10, 6))
numeric_df = df.select_dtypes(include=np.number)
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
#Correlation line plot off the variables
plt.figure(figsize=(10, 6))
plt.plot(numeric_df.corrwith(numeric_df['rating']).sort_values(ascending=False))
plt.title('Correlation Line Plot')
plt.xlabel('Variables')
plt.ylabel('Correlation')
plt.grid(True)
plt.show()

# %%
#Scatter plots and histograms
pd.plotting.scatter_matrix(numeric_df, figsize=(10, 10))
plt.show()

# %% [markdown]
# **Step 5 - Data Analysis**

# %%
#Rating Average and Rating Count
sns.lineplot(data=df, x='rating', y='rating_count')
plt.title('Rating Average and Rating Count')
plt.xlabel('Rating Average')
plt.ylabel('Rating Count')
plt.show()

# %%
#Number of ratings per 'rate_description'
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='rate_description', palette='RdYlGn')
for p in ax.patches:
    ax.annotate(str(int(p.get_height())),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),
                textcoords='offset points')
plt.title('Number of Ratings per Rate Description')
plt.xlabel('Rate Description')
plt.ylabel('Count')

plt.show()
# Out:
# <ipython-input-28-fc074d975d56>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='rate_description', palette='RdYlGn')

# %%
#Number of products per 'macro_category'
category_order = df['macro_category'].value_counts().index
ax = sns.countplot(data=df, x='macro_category', palette="viridis", order=category_order)
plt.title('Number of Products per Macro Category')
plt.xlabel('Macro Category')
plt.ylabel('Product Count')
plt.xticks(rotation=90)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),
                textcoords='offset points')

plt.show()
# Out:
# <ipython-input-29-593b4f768ff4>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='macro_category', palette="viridis", order=category_order)

# %%
#Most sold products per 'macro_category'
most_sold_macro_category = df['macro_category'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(17, 6))
ax = sns.barplot(x=most_sold_macro_category.index, y=most_sold_macro_category.values, palette='viridis')
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom',
                xytext=(0, 5),
                textcoords='offset points')
plt.title('Most Sold per Macro Category')
plt.xlabel('Macro Category')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-30-0386e5ba5124>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=most_sold_macro_category.index, y=most_sold_macro_category.values, palette='viridis')

# %%
#Rating average per "macro_category"
plt.figure(figsize=(15, 6))
ordered_categories = df.groupby('macro_category')['rating'].mean().sort_values(ascending=False).index
ax = sns.barplot(x='macro_category', y='rating', data=df, order=ordered_categories, palette='viridis')
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),
                textcoords='offset points')
plt.title('Rating Average per Macro Category')
plt.xlabel('Macro Category')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-31-e26589f6512b>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='macro_category', y='rating', data=df, order=ordered_categories, palette='viridis')

# %%
#Number of products per 'micro_category' (Top 10)
category_order = df['micro_category'].value_counts().nlargest(10).index
ax = sns.countplot(data=df, x='micro_category', palette="viridis", order=category_order)
plt.title('Number of Products per Micro Category (Top 10)')
plt.xlabel('Micro Category')
plt.ylabel('Product Count')
plt.xticks(rotation=90)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),
                textcoords='offset points')

plt.show()
# Out:
# <ipython-input-32-8c0ccbe92762>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='micro_category', palette="viridis", order=category_order)

# %%
#Most top 10 sold per 'micro_category'
most_sold_micro_category = df['micro_category'].value_counts().sort_values(ascending=False).head(10)
plt.figure(figsize=(17, 6))
ax = sns.barplot(x=most_sold_macro_category.index, y=most_sold_macro_category.values, palette='viridis')
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom',
                xytext=(0, 5),
                textcoords='offset points')
plt.title('Most Sold Micro Category')
plt.xlabel('Micro Category')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-33-15324192bace>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=most_sold_macro_category.index, y=most_sold_macro_category.values, palette='viridis')

# %%
#Rating average per 'micro_category' (Top 5 and bottom 5)
plt.figure(figsize=(16, 6))
ordered_micro_categories = df.groupby('micro_category')['rating'].mean().sort_values(ascending=False)
top_3_micro_categories = ordered_micro_categories.head(5)
bottom_3_micro_categories = ordered_micro_categories.tail(5)
selected_micro_categories = pd.concat([top_3_micro_categories, bottom_3_micro_categories])
ax = sns.barplot(x=selected_micro_categories.index, y=selected_micro_categories.values, palette='viridis')
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),
                textcoords='offset points')
plt.title('Rating Average per Micro Category (Top 5 and Bottom 5)')
plt.xlabel('Micro Category')
plt.ylabel('Rating')
plt.show()
# Out:
# <ipython-input-34-cbe4af5253bf>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=selected_micro_categories.index, y=selected_micro_categories.values, palette='viridis')

# %%
#Rating average per 'product_name' (top 5 and bottom 5)
plt.figure(figsize=(15, 6))
ordered_products = df.groupby('product_name')['rating'].mean().sort_values(ascending=False)
top_3_products = ordered_products.head(5)
bottom_3_products = ordered_products.tail(5)
selected_products = pd.concat([top_3_products, bottom_3_products])
ax = sns.barplot(x=selected_products.index, y=selected_products.values, palette='viridis')
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),
                textcoords='offset points')
plt.title('Rating Average per Product Name (Top 5 and Bottom 5)')
plt.xlabel('Product Name')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-35-818de9b2d437>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=selected_products.index, y=selected_products.values, palette='viridis')
